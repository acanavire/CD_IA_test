# %% [markdown]
# # **Ciencia de Datos e Inteligencia Artificial**
# # **2. Fundamentos para empezar en CD e IA**
# Estos ejercicios simples son para el cuestionario práctico (usando coderruner en moodle).

# %% [markdown]
# 1. Crear una variable llamada x y asignarle el número entero 8. Imprimir resultado en pantalla usando print(x).

# %% [markdown]
# **Haz doble click para ver la respuesta**
#
# <!--
# x = 8
# print(x)
#  -->

# %% [markdown]
# 2. Mediante el uso de sentencia condicional indicar si un número (x) es par tal que si se cumple la condición se debe escribir en la pantalla el mensaje "Número par", sino "Número impar". Tener en cuenta la asignación de variable x, planteada en el ejercicio anterior.

# %% [markdown]
# **Haz doble click para ver la respuesta**
#
# <!--
# x = 8
# if x % 2 == 0:
#   print('Número par')
# else:
#   print('Número impar')
#  -->

# %% [markdown]
# 3. Crear la variable lista, de manera tal que `lista = [1,8,10,15,20]`. Recorrer los elementos de la lista e indicar si el elemento de la lista es número par o impar. Tener en cuenta el ejercicio anterior que valida si un número x e par o impar.

# %% [markdown]
# **Haz doble click para ver la respuesta**
#
# <!--
# lista = [1,8,10,15,20]
# for x in lista:
#   if x % 2 == 0:
#     print('Número par')
#   else:
#     print('Número impar')
#  -->
